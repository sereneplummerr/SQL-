# %% [markdown]
# <a href="https://colab.research.google.com/github/sereneplummerr/SQL-/blob/main/Lists%2C_Dictionaries%2C_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
produce = ["Cucumber", "Avacado", "GrapeFruit"] #devices #Lists
produce_info = {"name": "Cucumber", "stock": "none", "barcode": "692"} #device_info #Dictionaries
##network_devices #Creating a List of Dictionaries
stocked_produce = [{"name": "Cucumber", "stock": "none", "barcode": "692"},
                   {"name": "Avacado", "stock": "active", "barcode": "779"},
                   {"name": "GrapeFruit", "stock": "active", "barcode": "934"}]

# Accessing Dictionary Data
for produce in stocked_produce:
    print(f"Produce Name: {produce['name']}")
    print(f"Stock: {produce['stock']}")
    print(f"Barcode: {produce['barcode']}")
    print('---------------------------')

#Modifying Dictionary Data
for produce in stocked_produce:
    produce["stock"] = "active"
for produce in stocked_produce:
    print(f"{produce['name']} is now {produce['stock']}")

print('---------------------------')

#Adding and Removing Attributes
# Add productCode to the first produce
stocked_produce[0]["productCode"] = "192"
# Remove barcode from the second produce
#for i in range(3):
del stocked_produce[2]["barcode"]
print(stocked_produce)
print('---------------------------')

#Build Your Own List of Devices
my_produce=[]
my_produce.append({"name": "Cucumber", "stock": "none", "barcode": "692"})
my_produce.append({"name": "Avacado", "stock": "active", "barcode": "779"})
my_produce.append({"name": "GrapeFruit", "stock": "active", "barcode": "934"})

def add_produce(produce_list, name, stock, barcode):
    new_produce = {"name": name, "stock": stock, "barcode": barcode}
    produce_list.append(new_produce)
add_produce(my_produce, "Garlic", "active", "201")

print(my_produce)
print('---------------------------')
produce = ["Cucumber", "Avacado", "GrapeFruit"] #devices #Lists
produce_info = {"name": "Cucumber", "stock": "none", "barcode": "692"} #device_info #Dictionaries
##network_devices #Creating a List of Dictionaries
stocked_produce = [{"name": "Cucumber", "stock": "none", "barcode": "692"},
                   {"name": "Avacado", "stock": "active", "barcode": "779"},
                   {"name": "GrapeFruit", "stock": "active", "barcode": "934"}]

# Accessing Dictionary Data
for produce in stocked_produce:
    print(f"Produce Name: {produce['name']}")
    print(f"Stock: {produce['stock']}")
    print(f"Barcode: {produce['barcode']}")
    print('---------------------------')

#Modifying Dictionary Data
for produce in stocked_produce:
    produce["stock"] = "active"
for produce in stocked_produce:
    print(f"{produce['name']} is now {produce['stock']}")

print('---------------------------')

#Adding and Removing Attributes
# Add productCode to the first produce
stocked_produce[0]["productCode"] = "192"
# Remove barcode from the second produce
#for i in range(3):
del stocked_produce[1]["barcode"]
print(stocked_produce)
print('---------------------------')

#Build Your Own List of Devices
my_produce=[]
my_produce.append({"name": "Cucumber", "stock": "none", "barcode": "692"})
my_produce.append({"name": "Avacado", "stock": "active", "barcode": "779"})
my_produce.append({"name": "GrapeFruit", "stock": "active", "barcode": "934"})

def add_produce(produce_list, name, stock, barcode):
    new_produce = {"name": name, "stock": stock, "barcode": barcode}
    produce_list.append(new_produce) # Corrected: use append method of the list

add_produce(my_produce, "Garlic", "active", "201") # Corrected: call the function outside of the function definition

print(my_produce)
print('---------------------------')

#Bulk Status Update
print("Before update:")
for produce in my_produce:
    print(produce)
for produce in my_produce:
    produce["status"] = "stocking"
print("\nAfter update:")
for produce in my_produce:
    print(produce)

#Add/Remove Attributes
my_produce[0]["productCode"] = "192"
del my_produce[1]["barcode"]
print(my_produce)

#Filtering
my_produce = [
    {"name": "Cucumber", "type": "vegetable"},
    {"name": "Avacado", "type": "fruit"},
    {"name": "GrapeFruit", "type": "fruit"},
    {"name": "Garlic", "type": "vegetable"}]

def add_produce_attributes(produce_list):
    for produce in produce_list:
        produce["stock"]="active"
        produce["barcode"] = "123"
        produce["supplier"] = "Local Farm"




# Call the function to add attributes
add_produce_attributes(my_produce)

# Print the updated produce list
print("Produce with attributes:")
for produce in my_produce:
    print(produce)

# Filter produce by stock (active)
stocked_produce = [p for p in my_produce if p["stock"] == "active"]

# Print the filtered list
print("\nStocked produce:", stocked_produce)
# Out:
# Produce Name: Cucumber
# Stock: none
# Barcode: 692
# ---------------------------
# Produce Name: Avacado
# Stock: active
# Barcode: 779
# ---------------------------
# Produce Name: GrapeFruit
# Stock: active
# Barcode: 934
# ---------------------------
# Cucumber is now active
# Avacado is now active
# GrapeFruit is now active
# ---------------------------
# [{'name': 'Cucumber', 'stock': 'active', 'barcode': '692', 'productCode': '192'}, {'name': 'Avacado', 'stock': 'active', 'barcode': '779'}, {'name': 'GrapeFruit', 'stock': 'active'}]
# ---------------------------
# [{'name': 'Cucumber', 'stock': 'none', 'barcode': '692'}, {'name': 'Avacado', 'stock': 'active', 'barcode': '779'}, {'name': 'GrapeFruit', 'stock': 'active', 'barcode': '934'}, {'name': 'Garlic', 'stock': 'active', 'barcode': '201'}]
# ---------------------------
# Produce Name: Cucumber
# Stock: none
# Barcode: 692
# ---------------------------
# Produce Name: Avacado
# Stock: active
# Barcode: 779
# ...
